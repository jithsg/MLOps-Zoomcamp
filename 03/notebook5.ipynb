# %%
import mlflow
import os

os.environ["AWS_PROFILE"] = "jithsg" # fill in with your AWS profile. More info: https://docs.aws.amazon.com/sdk-for-java/latest/developer-guide/setup.html#setup-credentials

TRACKING_SERVER_HOST = "ec2-34-224-21-16.compute-1.amazonaws.com" # fill in with the public DNS of the EC2 instance
mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:5000")

# %%
print(mlflow.get_tracking_uri())
# Out:
# http://ec2-34-224-21-16.compute-1.amazonaws.com:5000

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='s3://mlops-jith/1', creation_time=1706181059968, experiment_id='1', last_update_time=1706181059968, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='s3://mlops-jith/0', creation_time=1706173676672, experiment_id='0', last_update_time=1706173676672, lifecycle_stage='active', name='Default', tags={}>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# /home/jithish/.cache/pypoetry/virtualenvs/zoomcamp-LVGFZID_-py3.11/lib/python3.11/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/jithish/.cache/pypoetry/virtualenvs/zoomcamp-LVGFZID_-py3.11/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# ---------------------------------------------------------------------------
# ProfileNotFound                           Traceback (most recent call last)
# Cell In[34], line 18
#      15 y_pred = lr.predict(X)
# ...

# %%
import mlflow
import os

os.environ["AWS_PROFILE"] = "" # fill in with your AWS profile.docs.aws.amazon.com/sdk-for-java/latest/developer-guide/setup.html#setup-credentials

TRACKING_SERVER_HOST = "" # fill in with the public DNS of the EC2 instance
mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:5000")
